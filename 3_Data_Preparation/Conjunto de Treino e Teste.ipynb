# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import cross_val_score,train_test_split, KFold, GroupKFold

# %%
path = 'dados/procucao_gado_MS.csv'
df = pd.read_csv(path, sep=';')

# %%
df.sample(3)
# Out:
#         tipificacao_1  tipificacao_2  tipificacao_3  maturidade  acabamento  \
# 231105              1              0              0           2           2
# 673482              0              1              0           2           2
# 282929              1              0              0           4           3
#
#          peso  classificacao_estabelecimento  outros_incentivos  \
# 231105  331.4                           26.0                  0
# 673482  241.0                           21.0                  0
# 282929  290.6                           21.0                  0
#
#         pratica_recuperacao_pastagem  fertiirrigacao  ...  cnt1m_cl_ituinst  \
# 231105                             0               0  ...            0.3793
# 673482                             0               0  ...            0.5161
# 282929                             0               0  ...            0.2069
#
#         cnt3m_cl_ituinst  cnt6m_cl_ituinst  cnt12m_cl_ituinst   ano  \
# 231105            0.3220            0.4224             0.4073  2017
# 673482            0.6452            0.5246             0.3525  2018
# 282929            0.2838            0.3621             0.3883  2017
#
#         categoria  classificacao  longitude   latitude  mes
# 231105          4              1 -51.418940 -20.366740   11
# 673482          4              1 -55.790616 -20.474654    9
# 282929          6              0 -52.036300 -21.247120   12
#
# [3 rows x 53 columns]

# %%
print('A base de dados apresenta {} registros e {} características.'.format(df.shape[0], df.shape[1]))
# Out:
# A base de dados apresenta 960939 registros e 53 características.

# %%
y = df['categoria']
# Retirar a variável alvo e as variáveis obtidas após o abate 
X = df.drop(['peso','acabamento', 'maturidade', 'classificacao','categoria', 'ano'],axis=1)

# %%
SEED = 42
gfolds = GroupKFold(n_splits=10)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2, random_state=SEED)

# %%
df_y_train = pd.DataFrame(y_train)
df_y_test = pd.DataFrame(y_test)

# %%
sns.catplot(x = "categoria", data = df_y_train, 
            kind="count", 
            aspect=2).set(title='Distribuição da Característica alvo no conjunto de treinamento')
sns.catplot(x = "categoria", data = df_y_test, 
            kind="count", 
            aspect=2).set(title='Distribuição da Característica alvo no conjunto de teste')

# %%
df_train = X_train.join(df_y_train)

# %%
df_train.to_csv("procucao_gado_MS_train", sep=';', index=False)

# %%
df_test = X_test.join(df_y_test)

# %%
df_test.to_csv("procucao_gado_MS_test", sep=';', index=False)

# %%
X_train.head(10)
# Out:
#         tipificacao_1  tipificacao_2  tipificacao_3  \
# 243656              1              0              0
# 901467              1              0              0
# 255725              0              1              0
# 663154              1              0              0
# 770948              1              0              0
# 722346              1              0              0
# 640139              1              0              0
# 618781              1              0              0
# 882243              0              1              0
# 453805              0              0              1
#
#         classificacao_estabelecimento  outros_incentivos  \
# 243656                           30.0                  0
# 901467                           26.0                  0
# 255725                           21.0                  0
# 663154                           21.0                  0
# 770948                           30.0                  0
# 722346                           30.0                  0
# 640139                           21.0                  0
# 618781                           21.0                  0
# 882243                           26.0                  0
# 453805                           21.0                  0
#
#         pratica_recuperacao_pastagem  fertiirrigacao  ilp  ilpf  ifp  ...  \
# 243656                             1               0    0     1    0  ...
# 901467                             0               0    0     0    0  ...
# 255725                             0               0    0     0    0  ...
# 663154                             1               0    1     0    0  ...
# 770948                             1               0    1     0    0  ...
# 722346                             1               0    1     0    0  ...
# 640139                             0               0    0     0    0  ...
# 618781                             0               0    0     0    0  ...
# 882243                             0               0    0     0    0  ...
# 453805                             0               0    0     0    0  ...
#
#         med12m_prer_soja  med12m_prer_milho  med12m_prer_boi  \
# 243656             71.03              30.31           138.22
# 901467             83.92              38.09           144.57
# 255725             71.10              30.32           138.33
# 663154             79.61              36.44           143.00
# 770948             82.62              37.62           143.89
# 722346             81.54              37.27           143.51
# 640139             79.11              36.14           142.90
# 618781             78.47              35.71           142.66
# 882243             83.75              37.96           144.49
# 453805             73.72              31.88           139.33
#
#         cnt1m_cl_ituinst  cnt3m_cl_ituinst  cnt6m_cl_ituinst  \
# 243656            0.5000            0.6538            0.7500
# 901467            0.5161            0.5699            0.7213
# 255725            0.5484            0.6129            0.7104
# 663154            0.8387            0.8495            0.7923
# 770948            0.5161            0.7742            0.8087
# 722346            0.7667            0.8652            0.9143
# 640139            0.8387            0.7849            0.6066
# 618781            0.8387            0.7742            0.5574
# 882243            0.4839            0.5591            0.7049
# 453805            0.8710            0.7097            0.6175
#
#         cnt12m_cl_ituinst  longitude   latitude  mes
# 243656             0.6182 -53.761680 -20.443680   11
# 901467             0.6685 -55.281910 -20.692310   12
# 255725             0.6460 -52.425437 -21.715288   12
# 663154             0.6831 -54.865560 -20.442310    9
# 770948             0.6514 -53.351570 -22.248760   10
# 722346             0.8023 -54.564569 -19.395521   10
# 640139             0.4388 -52.036300 -21.247120    8
# 618781             0.4198 -52.036300 -21.247120    8
# 882243             0.6749 -54.892770 -19.961860   11
# 453805             0.6530 -54.830010 -19.831220    5
#
# [10 rows x 47 columns]

# %%
y_train.head(10)
# Out:
# 243656    1
# 901467    2
# 255725    5
# 663154    2
# 770948    4
# 722346    2
# 640139    6
# 618781    2
# 882243    3
# 453805    6
# Name: categoria, dtype: int64
